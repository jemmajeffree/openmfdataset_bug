# %%
import sys
sys.path.append('/glade/u/home/jjeffree/pca_calculation_scripts/self_contained_problem/')
import problem

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
# Out:
# /glade/u/home/jjeffree/.conda/envs/jj_default/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37389 instead
#   warnings.warn(

# %%
import xarray as xr

filenames = ['/glade/campaign/cgd/cesm/CESM2-LE/timeseries/ocn/proc/tseries/month_1/SSH/b.e21.BHISTcmip6.f09_g17.LE2-1001.001.pop.h.SSH.185001-185912.nc',
  '/glade/campaign/cgd/cesm/CESM2-LE/timeseries/ocn/proc/tseries/month_1/SSH/b.e21.BHISTcmip6.f09_g17.LE2-1021.002.pop.h.SSH.185001-185912.nc']

xr.open_mfdataset(filenames,
                  coords='minimal',
                        compat='override',
                        combine = 'nested',
                        concat_dim = ('SMILE_M',),
                       parallel = True,
                 )
# Out:
# <xarray.Dataset>
# Dimensions:                 (SMILE_M: 2, moc_comp: 3, transport_comp: 5,
#                              transport_reg: 2, z_t: 60, z_t_150m: 15, z_w: 60,
#                              z_w_top: 60, z_w_bot: 60, lat_aux_grid: 395,
#                              moc_z: 61, nlat: 384, nlon: 320, time: 120, d2: 2)
# Coordinates:
#   * z_t                     (z_t) float32 500.0 1.5e+03 ... 5.125e+05 5.375e+05
#   * z_t_150m                (z_t_150m) float32 500.0 1.5e+03 ... 1.45e+04
#   * z_w                     (z_w) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_top                 (z_w_top) float32 0.0 1e+03 2e+03 ... 5e+05 5.25e+05
#   * z_w_bot                 (z_w_bot) float32 1e+03 2e+03 ... 5.25e+05 5.5e+05
#   * lat_aux_grid            (lat_aux_grid) float32 -79.49 -78.95 ... 89.47 90.0
#   * moc_z                   (moc_z) float32 0.0 1e+03 2e+03 ... 5.25e+05 5.5e+05
# ...
